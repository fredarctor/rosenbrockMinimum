# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import matplotlib.ticker as ticker
import pandas as pd

# %%
utwo = pd.read_csv('../Data/E2part3.csv')

u = utwo['log'].dropna()
n = utwo['logfreq'].dropna()

plt.plot(n,u)
